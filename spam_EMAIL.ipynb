# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
df=pd.read_csv('/content/drive/MyDrive/Datasets/Spam_naive_bayes_thery.csv')
df
# Out:
#      Category                                            Message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
# df['Message'].value_counts()

# %%
df['Category']=df['Category'].replace({'spam':1,'ham':0})
df
# Out:
#       Category                                            Message
# 0            0  Go until jurong point, crazy.. Available only ...
# 1            0                      Ok lar... Joking wif u oni...
# 2            1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3            0  U dun say so early hor... U c already then say...
# 4            0  Nah I don't think he goes to usf, he lives aro...
# ...        ...                                                ...
# 5567         1  This is the 2nd time we have tried 2 contact u...
# 5568         0               Will ü b going to esplanade fr home?
# 5569         0  Pity, * was in mood for that. So...any other s...
# 5570         0  The guy did some bitching but I acted like i'd...
# 5571         0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
x=df['Message']
y=df['Category']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer=CountVectorizer()
x_train=vectorizer.fit_transform(x_train)
x_test=vectorizer.transform(x_test)

# %%
from sklearn.naive_bayes import MultinomialNB
# model=MultinomialNB()
# model.fit(x_train,y_train)
from sklearn.naive_bayes import MultinomialNB,GaussianNB,BernoulliNB
model=MultinomialNB()
model.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import classification_report,accuracy_score
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 98.85139985642498

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1207
#            1       0.98      0.94      0.96       186
#
#     accuracy                           0.99      1393
#    macro avg       0.98      0.97      0.97      1393
# weighted avg       0.99      0.99      0.99      1393

# %% [markdown]
# OVERSAMPLE AND UNDERSAMPLE USING RANDOMOVERSAMPLER

# %%
x_vector=vectorizer.fit_transform(x)

# %%
from imblearn.over_sampling import RandomOverSampler
over=RandomOverSampler()
x_over,y_over=over.fit_resample(x_vector,y)

from imblearn.under_sampling import RandomUnderSampler
under=RandomUnderSampler()
x_under,y_under=under.fit_resample(x_vector,y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_over,y_over,test_size=0.4,random_state=50)

# %% [markdown]
# BUILDING MODEL USING SVM AND KNN

# %%
#  oversampled result
sv=SVC()
kn=KNeighborsClassifier()
mn=MultinomialNB()
models=[sv,kn,mn]
evaluation={'name':[],'accuracy':[]}
for model in models:
  model.fit(x_train,y_train)
  y_pred=model.predict(x_test)
  accuracy=accuracy_score(y_test,y_pred)
  evaluation['name'].append(model)
  evaluation['accuracy'].append(accuracy)
  print(model)
  print(classification_report(y_test,y_pred))
  print(accuracy_score(y_test,y_pred))
  print('--------------------------------------------------------')
# Out:
# SVC()
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1934
#            1       1.00      0.99      0.99      1926
#
#     accuracy                           0.99      3860
#    macro avg       0.99      0.99      0.99      3860
# weighted avg       0.99      0.99      0.99      3860
#
# 0.9924870466321244
# --------------------------------------------------------
# KNeighborsClassifier()
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      1934
#            1       1.00      0.90      0.95      1926
#
#     accuracy                           0.95      3860
#    macro avg       0.95      0.95      0.95      3860
# weighted avg       0.95      0.95      0.95      3860
#
# 0.9507772020725389
# --------------------------------------------------------
# MultinomialNB()
#               precision    recall  f1-score   support
#
# ...

# %%
pd.DataFrame(evaluation)
# Out:
#                      name  accuracy
# 0                   SVC()  0.992487
# 1  KNeighborsClassifier()  0.950777
# 2         MultinomialNB()  0.982902

# %%
def predict_spam(sample_message):
  sample_message=vectorizer.transform([sample_message])
  result=model.predict(sample_message)
  if result==1:
    return "This is a spam message"
  else:
    return "This is not a spam message"

# %%
# Example usage:
sample_message = "Congratulations! You've won a free iPhone!"
prediction = predict_spam(sample_message)
print(prediction)
# Out:
# This is a spam message

# %%
# Example usage:
sample_message = "Please be available for today's meeting at noon"
prediction = predict_spam(sample_message)
print(prediction)
# Out:
# This is not a spam message
